# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("postgresql+psycopg2://postgres:barTu6-nidwet-magboh@localhost/smart_health")

df = pd.read_sql("SELECT * FROM answers LIMIT 100", engine)
print(df.head())
# Out:
#         id              element_slug answer  completion_id  \
# 0  2417900     ls_sleep_type_1_quiet      1          46700
# 1  2417901   ls_sleep_type_1_tension      0          46700
# 2  2417902  ls_sleep_type_1_thoughts      1          46700
# 3  2417903  ls_sleep_type_2_headache      1          46700
# 4  2417904      ls_sleep_type_2_naps      0          46700
#
#            created_at          updated_at
# 0 2019-03-11 16:56:58 2025-08-13 21:25:56
# 1 2019-03-11 16:56:58 2025-08-13 21:25:56
# 2 2019-03-11 16:56:58 2025-08-13 21:25:56
# 3 2019-03-11 16:56:58 2025-08-13 21:25:56
# 4 2019-03-11 16:56:58 2025-08-13 21:25:56

# %%
df_all = pd.read_sql("SELECT * FROM answers", engine)

df_wide = df_all.pivot_table(
    index="completion_id", 
    columns="element_slug", 
    values="answer", 
    aggfunc="first"
).reset_index()

print(df_wide.shape)
print(df_wide.head())
# Out:
# (19113, 645)
# element_slug  completion_id 10_dass_nothing_looking_forward  \
# 0                     45441                             NaN
# 1                     45442                             NaN
# 2                     45443                             NaN
# 3                     45444                             NaN
# 4                     45445                             NaN
#
# element_slug 11_dass_upset_easily 12_dass_nervous_energy  \
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             NaN                    NaN
# 3                             NaN                    NaN
# 4                             NaN                    NaN
#
# element_slug 13_dass_sad_depressed 14_dass_impatient 15_dass_faintness  \
# 0                              NaN               NaN               NaN
# 1                              NaN               NaN               NaN
# 2                              NaN               NaN               NaN
# 3                              NaN               NaN               NaN
# 4                              NaN               NaN               NaN
#
# element_slug 16_dass_lost_interest 17_dass_self_worth 18_dass_touchy  ...  \
# 0                              NaN                NaN            NaN  ...
# 1                              NaN                NaN            NaN  ...
# 2                              NaN                NaN            NaN  ...
# 3                              NaN                NaN            NaN  ...
# 4                              NaN                NaN            NaN  ...
#
# element_slug user_dob_year user_gender user_gender_inclusive user_origen  \
# 0                     1989           1                   NaN         NaN
# 1                      NaN         NaN                   NaN         NaN
# 2                     1949           1                   NaN         NaN
# 3                      NaN         NaN                   NaN           0
# 4                      NaN         NaN                   NaN         NaN
#
# element_slug weight wellbeing_active wellbeing_fresh wellbeing_happy  \
# 0               NaN              NaN             NaN             NaN
# 1               NaN              NaN             NaN             NaN
# 2               NaN              NaN             NaN             NaN
# 3               NaN              NaN             NaN             NaN
# 4                70              NaN             NaN             NaN
#
# element_slug wellbeing_interested wellbeing_relaxed
# 0                             NaN               NaN
# 1                             NaN               NaN
# 2                             NaN               NaN
# 3                             NaN               NaN
# 4                             NaN               NaN
#
# [5 rows x 645 columns]

# %%
df_all = pd.read_sql("SELECT * FROM answers", engine)

df_wide = df_all.pivot_table(
    index="completion_id", 
    columns="element_slug", 
    values="answer", 
    aggfunc="first"
).reset_index()

print(df_wide.shape)
print(df_wide.head())
# Out:
# (19113, 645)
# element_slug  completion_id 10_dass_nothing_looking_forward  \
# 0                     45441                             NaN
# 1                     45442                             NaN
# 2                     45443                             NaN
# 3                     45444                             NaN
# 4                     45445                             NaN
#
# element_slug 11_dass_upset_easily 12_dass_nervous_energy  \
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             NaN                    NaN
# 3                             NaN                    NaN
# 4                             NaN                    NaN
#
# element_slug 13_dass_sad_depressed 14_dass_impatient 15_dass_faintness  \
# 0                              NaN               NaN               NaN
# 1                              NaN               NaN               NaN
# 2                              NaN               NaN               NaN
# 3                              NaN               NaN               NaN
# 4                              NaN               NaN               NaN
#
# element_slug 16_dass_lost_interest 17_dass_self_worth 18_dass_touchy  ...  \
# 0                              NaN                NaN            NaN  ...
# 1                              NaN                NaN            NaN  ...
# 2                              NaN                NaN            NaN  ...
# 3                              NaN                NaN            NaN  ...
# 4                              NaN                NaN            NaN  ...
#
# element_slug user_dob_year user_gender user_gender_inclusive user_origen  \
# 0                     1989           1                   NaN         NaN
# 1                      NaN         NaN                   NaN         NaN
# 2                     1949           1                   NaN         NaN
# 3                      NaN         NaN                   NaN           0
# 4                      NaN         NaN                   NaN         NaN
#
# element_slug weight wellbeing_active wellbeing_fresh wellbeing_happy  \
# 0               NaN              NaN             NaN             NaN
# 1               NaN              NaN             NaN             NaN
# 2               NaN              NaN             NaN             NaN
# 3               NaN              NaN             NaN             NaN
# 4                70              NaN             NaN             NaN
#
# element_slug wellbeing_interested wellbeing_relaxed
# 0                             NaN               NaN
# 1                             NaN               NaN
# 2                             NaN               NaN
# 3                             NaN               NaN
# 4                             NaN               NaN
#
# [5 rows x 645 columns]

# %%
df_sample = pd.read_sql("SELECT * FROM answers LIMIT 10000", engine)

df_wide = df_sample.pivot_table(
    index="completion_id", 
    columns="element_slug", 
    values="answer", 
    aggfunc="first"
).reset_index()

print(df_wide.shape)
print(df_wide.columns.tolist())
# Out:
# (295, 200)
# ['completion_id', 'height', 'hr_blood_pressure_high_history', 'hr_blood_pressure_non_invasive', 'hr_cvd_history', 'hr_diabetes', 'hr_diabetes_in_family', 'hr_diabetes_type', 'hr_hereditary_heart_disease', 'hr_medication_blood_pressure', 'hr_medication_cholesterol', 'hr_rheumatism', 'ls_alcohol_friday', 'ls_alcohol_monday', 'ls_alcohol_saturday', 'ls_alcohol_sunday', 'ls_alcohol_thursday', 'ls_alcohol_tuesday', 'ls_alcohol_wednesday', 'ls_exercise_physical_activity_balance', 'ls_exercise_physical_activity_moderate_fri_hours', 'ls_exercise_physical_activity_moderate_fri_min', 'ls_exercise_physical_activity_moderate_mon_hours', 'ls_exercise_physical_activity_moderate_mon_min', 'ls_exercise_physical_activity_moderate_sat_hours', 'ls_exercise_physical_activity_moderate_sat_min', 'ls_exercise_physical_activity_moderate_sun_hours', 'ls_exercise_physical_activity_moderate_sun_min', 'ls_exercise_physical_activity_moderate_thu_hours', 'ls_exercise_physical_activity_moderate_thu_min', 'ls_exercise_physical_activity_moderate_tue_hours', 'ls_exercise_physical_activity_moderate_tue_min', 'ls_exercise_physical_activity_moderate_wed_hours', 'ls_exercise_physical_activity_moderate_wed_min', 'ls_exercise_physical_activity_muscle_bone', 'ls_exercise_physical_activity_vigorous_fri_hours', 'ls_exercise_physical_activity_vigorous_fri_min', 'ls_exercise_physical_activity_vigorous_mon_hours', 'ls_exercise_physical_activity_vigorous_mon_min', 'ls_exercise_physical_activity_vigorous_sat_hours', 'ls_exercise_physical_activity_vigorous_sat_min', 'ls_exercise_physical_activity_vigorous_sun_hours', 'ls_exercise_physical_activity_vigorous_sun_min', 'ls_exercise_physical_activity_vigorous_thu_hours', 'ls_exercise_physical_activity_vigorous_thu_min', 'ls_exercise_physical_activity_vigorous_tue_hours', 'ls_exercise_physical_activity_vigorous_tue_min', 'ls_exercise_physical_activity_vigorous_wed_hours', 'ls_exercise_physical_activity_vigorous_wed_min', 'ls_exercise_sitting_hours', 'ls_exercise_sitting_minutes', 'ls_exercise_steps_per_day', 'ls_exercise_walking_days', 'ls_exercise_walking_hours', 'ls_exercise_walking_minutes', 'ls_fluid_else_days', 'ls_fluid_else_glasses', 'ls_fluid_hotdrinks_days', 'ls_fluid_hotdrinks_glasses', 'ls_fluid_supplement_days', 'ls_fluid_supplement_glasses', 'ls_fluid_vegjuice_days', 'ls_fluid_vegjuice_glasses', 'ls_fluid_water_days', 'ls_fluid_water_glasses', 'ls_medical_physical_limitations', 'ls_nutrition_bake', 'ls_nutrition_biscuit_days', 'ls_nutrition_biscuit_pieces', 'ls_nutrition_biscuits_cake_days', 'ls_nutrition_biscuits_cake_pieces', 'ls_nutrition_bread_cereal', 'ls_nutrition_bread_cheese_type', 'ls_nutrition_bread_days', 'ls_nutrition_bread_filling_cheese_days', 'ls_nutrition_bread_filling_cheese_pieces', 'ls_nutrition_bread_filling_choco', 'ls_nutrition_bread_filling_meat_slices', 'ls_nutrition_bread_filling_sweet', 'ls_nutrition_bread_slice', 'ls_nutrition_bread_spread', 'ls_nutrition_breakfast_days', 'ls_nutrition_candy_days', 'ls_nutrition_candy_pieces', 'ls_nutrition_candybars', 'ls_nutrition_chicken', 'ls_nutrition_chicken_fish_burger_days', 'ls_nutrition_chocolate_days', 'ls_nutrition_chocolate_milk_days', 'ls_nutrition_chocolate_milk_glasses', 'ls_nutrition_chocolate_milk_type', 'ls_nutrition_chocolate_type', 'ls_nutrition_crisps_days', 'ls_nutrition_custard_bowls', 'ls_nutrition_custard_days', 'ls_nutrition_diet_type', 'ls_nutrition_dinner_cheese_days', 'ls_nutrition_fish_days', 'ls_nutrition_fish_fingers_days', 'ls_nutrition_fries_days', 'ls_nutrition_fries_spoons', 'ls_nutrition_fruit_days', 'ls_nutrition_fruit_juice_days', 'ls_nutrition_fruit_juice_glasses', 'ls_nutrition_fruit_pieces', 'ls_nutrition_fruit_yoghurt_bowls', 'ls_nutrition_fruit_yoghurt_days', 'ls_nutrition_fruit_yoghurt_type', 'ls_nutrition_gravy_days', 'ls_nutrition_gravy_spoon_size', 'ls_nutrition_gravy_spoons', 'ls_nutrition_icecream_days', 'ls_nutrition_legumes', 'ls_nutrition_lettuce_days', 'ls_nutrition_lettuce_spoons', 'ls_nutrition_meat_s ...

# %%
df_wide.to_parquet("/Users/bliekendaal/Desktop/Code/pmo_data.parquet")

# %%
df_all = pd.read_sql("SELECT * FROM answers", engine)

df_wide_full = df_all.pivot_table(
    index="completion_id", 
    columns="element_slug", 
    values="answer", 
    aggfunc="first"
).reset_index()

df_wide_full.to_parquet("/Users/bliekendaal/Desktop/Code/pmo_data.parquet")
print(df_wide_full.shape)
# Out:
# (19113, 645)

# %%
df_wide_full.to_parquet("/Users/bliekendaal/Desktop/Code/pmo_data.parquet")
print("Opgeslagen!")
# Out:
# Opgeslagen!

# %%
df = pd.read_parquet("/Users/bliekendaal/Desktop/Code/pmo_data.parquet")

# %%
from sqlalchemy import text

with engine.connect() as conn:
    result = conn.execute(text("""
        SELECT table_name 
        FROM information_schema.tables 
        WHERE table_schema = 'public'
        ORDER BY table_name
    """))
    tabellen = [row[0] for row in result]
    print(tabellen)
# Out:
# ['activity_log', 'addresses', 'admins', 'advised_products', 'answers', 'automated_suggestions', 'categories', 'categorizables', 'challenge_giveaway_translations', 'challenge_leaderboard_translations', 'challenge_leaderboard_users', 'challenge_leaderboards', 'challenge_translations', 'challenge_week_translation_content', 'challenge_week_translation_products', 'challenge_week_translations', 'challenge_weeks', 'challenges', 'collected_products', 'completion_scores', 'completions', 'content', 'content_managers', 'content_translations', 'data_changes', 'demo_user_managers', 'demo_users', 'excluded_stores_from_group_challenges', 'factor_history_questionnaires', 'factor_score_histories', 'failed_jobs', 'favorites', 'featured_challenges_disabled_in_stores', 'health_check_result_history_items', 'health_index_info_blocks', 'hr_managers', 'immutable_products', 'immutable_providers', 'integrations', 'interactions', 'invitations', 'job_batches', 'jobs', 'latest_scores', 'media', 'migrations', 'monitored_scheduled_task_log_items', 'monitored_scheduled_tasks', 'my_clic_participants', 'news_notifications', 'news_notifications_dismissed', 'not_found_exceptions', 'notifications', 'oauth_access_tokens', 'oauth_auth_codes', 'oauth_clients', 'oauth_device_codes', 'oauth_refresh_tokens', 'operations', 'order_accepted_terms', 'orders', 'outgoing_api_connection_records', 'participants', 'partners', 'password_reset_tokens', 'payments', 'personal_access_tokens', 'products', 'project_managers', 'provider_admins', 'provider_products', 'provider_terms', 'providers', 'questionnaire_elements', 'questionnaire_factors', 'questionnaire_pages', 'questionnaire_pages_elements', 'questionnaire_sections', 'questionnaires', 'related_items', 'searched_locations', 'selection_group_items', 'selection_group_rulesets', 'selection_groups', 'selection_rules', 'selection_rulesets', 'shopping_carts', 'smile_pack_usages', 'smile_packs', 'smile_rewards', 'social_accounts', 'stock_mutations', 'store_always_unlocked_questionnaires', 'store_average_scores', 'store_disabled_categories', 'store_disabled_challenge_giveaways', 'store_disabled_challenge_leaderboards', 'store_disabled_challenges', 'store_disabled_content', 'store_disabled_news_notifications', 'store_disabled_products', 'store_disabled_providers', 'store_employee_budget_usages', 'store_employee_budgets', 'store_employee_filter_options', 'store_employee_filters', 'store_employee_number_ranges', 'store_employee_possible_answers', 'store_employee_question_answers', 'store_employee_selected_filter_options', 'store_employees', 'store_enabled_questionnaires', 'store_highlighted_categories', 'store_highlighted_products', 'stores', 'super_admins', 'task_events', 'tasks', 'unsubmitted_answers', 'user_challenge_smile_rewards', 'user_challenges', 'user_roles', 'user_smile_rewards', 'users']

# %%
relevante_tabellen = [
    "completions", "completion_scores", "latest_scores", 
    "store_average_scores", "factor_score_histories",
    "users", "store_employees", "questionnaire_elements"
]

for tabel in relevante_tabellen:
    df = pd.read_sql(f"SELECT * FROM {tabel}", engine)
    df.to_parquet(f"/Users/bliekendaal/Desktop/Code/{tabel}.parquet")
    print(f"✓ {tabel}: {df.shape}")
# Out:
# ✓ completions: (19113, 6)
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[11], line 9
#       5 ]
#       6
#       7 for tabel in relevante_tabellen:
#       8     df = pd.read_sql(f"SELECT * FROM {tabel}", engine)
# ----> 9     df.to_parquet(f"/Users/bliekendaal/Desktop/Code/{tabel}.parquet")
#      10     print(f"✓ {tabel}: {df.shape}")
#
# File /opt/homebrew/lib/python3.14/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.14/site-packages/pandas/core/frame.py:3124, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    3120         >>> content = f.read()
#    3121         """
#    3122         from pandas.io.parquet import to_parquet
#    3123
# -> 3124         return to_parquet(
#    3125             self,
#    3126             path,
#    3127             engine,
#
# File /opt/homebrew/lib/python3.14/site-packages/pandas/io/parquet.py:482, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     478 impl = get_engine(engine)
#     480 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
# --> 482 impl.write(
#     483     df,
#     484     path_or_buf,
#     485     compression=compression,
#     486     index=index,
#     487     partition_cols=partition_cols,
#     488     storage_options=storage_options,
#     489     filesystem=filesystem,
#     490     **kwargs,
#     491 )
#     493 if path is None:
#     494     assert isinstance(path_or_buf, io.BytesIO)
#
# File /opt/homebrew/lib/python3.14/site-packages/pandas/io/parquet.py:191, in PyArrowImpl.write(self, df, path, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     188 if index is not None:
#     189     from_pandas_kwargs["preserve_index"] = index
# --> 191 table = self.api.Table.from_pandas(df, **from_pandas_kwargs)
#     193 if df.attrs:
#     194     df_metadata = {"PANDAS_ATTRS": json.dumps(df.attrs)}
#
# File pyarrow/table.pxi:4796, in pyarrow.lib.Table.from_pandas()
# -> 4796 'Could not get source, probably due dynamically evaluated source code.'
#
# File /opt/homebrew/lib/python3.14/site-packages/pyarrow/pandas_compat.py:664, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     662     for i, maybe_fut in enumerate(arrays):
#     663         if isinstance(maybe_fut, futures.Future):
# --> 664             arrays[i] = maybe_fut.result()
#     666 types = [x.type for x in arrays]
#     668 if schema is None:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.3_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py:443, in Future.result(self, timeout)
#     441     raise CancelledError()
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#     447 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/homebrew/Cellar/python@3.14/3.14.3_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File /opt/homebrew/Cellar/python@3.14/3.14.3_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/thread.py:86, in _WorkItem.run(self, ctx)
#      83     return
#      85 try:
# ---> 86     result = ctx.run(self.task)
#      87 except BaseException as exc:
#      88     self.future.set_exception(exc)
#
# File /opt/homebrew/Cellar/python@3.14/3.14.3_1/Frameworks/Python.framework/Versions/3.14/lib/python3.14/concurrent/futures/thread.py:73, in WorkerContext.run(self, task)
#      71 def run(self, task):
#      72     fn, args, kwargs = task
# ---> 73     return fn(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.14/site-packages/pyarrow/pandas_compat.py:639, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     634 except (pa.ArrowInvalid,
#     635         pa.ArrowNotImplementedError,
#     636         pa.ArrowTypeError) as e:
#     637     e.args += (
#     638         f"Conversion failed for column {col.name} with type {col.dtype}",)
# --> 639     raise e
#     640 if not field_nullable and result.null_count > 0:
#     641     raise ValueError(f"Field {field} was non-nullable but pandas column "
#     642                      f"had {result.null_count} null values")
#
# File /opt/homebrew/lib/python3.14/site-packages/pyarrow/pandas_compat.py:633, in dataframe_to_arrays.<locals>.convert_column(col, field)
#     630     type_ = field.type
#     632 try:
# --> 633     result = pa.array(col, type=type_, from_pandas=True, safe=safe)
#     634 except (pa.ArrowInvalid,
#     635         pa.ArrowNotImplementedError,
#     636         pa.ArrowTypeError) as e:
#     637     e.args += (
#     638         f"Conversion failed for column {col.name} with type {col.dtype}",)
#
# File pyarrow/array.pxi:365, in pyarrow.lib.array()
# --> 365 'Could not get source, probably due dynamically evaluated source code.'
#
# File pyarrow/array.pxi:91, in pyarrow.lib._ndarray_to_array()
# ---> 91 'Could not get source, probably due dynamically evaluated source code.'
#
# File pyarrow/error.pxi:92, in pyarrow.lib.check_status()
# ---> 92 'Could not get source, probably due dynamically evaluated source code.'
#
# ArrowInvalid: ("Could not convert 'Good (below 140 mmHg)' with type str: tried to convert to double", 'Conversion failed for column value with type object')

# %%
relevante_tabellen = [
    "completions", "completion_scores", "latest_scores", 
    "store_average_scores", "factor_score_histories", "latest_scores",
    "users", "store_employees", "questionnaire_elements", "addresses", #"factor_scores",
    "latest_scores", "my_clic_participants", #"pmo_data", "pmo_werkbaar", 
    "questionnaire_elements", "store_average_scores", "store_employees", "stores", #"users_met_scores"
    #"users_mysql", 
    "users"
]

for tabel in relevante_tabellen:
    df = pd.read_sql(f"SELECT * FROM {tabel}", engine)
    # Gemengde kolommen omzetten naar string
    for col in df.columns:
        if df[col].dtype == object:
            df[col] = df[col].astype(str)
    df.to_parquet(f"/Users/bliekendaal/Desktop/Code/{tabel}.parquet")
    print(f"✓ {tabel}: {df.shape}")
# Out:
# ✓ completions: (19113, 6)
# ✓ completion_scores: (4324460, 6)
# ✓ latest_scores: (1050285, 6)
# ✓ store_average_scores: (617720, 7)
# ✓ factor_score_histories: (77017, 9)
# ✓ latest_scores: (1050285, 6)
# ✓ users: (5, 13)
# ✓ store_employees: (9124, 10)
# ✓ questionnaire_elements: (611, 14)
# ✓ addresses: (9820, 18)
# ✓ latest_scores: (1050285, 6)
# ✓ my_clic_participants: (6904, 8)
# ✓ questionnaire_elements: (611, 14)
# ✓ store_average_scores: (617720, 7)
# ✓ store_employees: (9124, 10)
# ✓ stores: (52, 22)
# ✓ users: (5, 13)
