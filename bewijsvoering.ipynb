# %% [markdown]
# # Bewijsvoering - Upload Checklist
#
# ## PO - Professionele Competenties

# %% [markdown]
# ### 3.1 Effectieve communicatie & verslaglegging
# - [ ] **Tussentijdse evaluatie** → UPLOAD: Tussentijdse_evaluatie_feedback.md
# - [ ] **Demo's (screenshots)** → MAAK: Screenshot agenda/kalender met demo-afspraken (datum zichtbaar)
# - [ ] **Schriftelijke rapportage voortgang** → MAAK: Voortgangsrapport (1-2 pagina's waarin je voortgang samenvat)

# %% [markdown]
# ### 3.2 Organisatie-inzicht & samenwerking
# - [ ] **Interview Jorg** → UPLOAD: Transcripties_Interviews_SmartHealth.md (interview 1)
# - [ ] **Interview Lieke** → UPLOAD: Transcripties_Interviews_SmartHealth.md (interview 2)
# - [ ] **Reflectie interviews** → UPLOAD: Reflectieverslag_Interviews_SmartHealth.md
# - [ ] **Organisatiestructuur analyse** → MAAK: Korte beschrijving hoe Smart Health in elkaar zit + jouw plek

# %% [markdown]
# ### 3.3 Zelfmanagement & professionele verantwoordelijkheid
# - [ ] **GitLab Scrumboard** → UPLOAD: 3x screenshot (week 1-5, 6-10, 11-16)
# - [ ] **VSCode Timeline** → UPLOAD: Screenshot versiegeschiedenis key files (dashboard.py, ml_model.py, DPIA.md)
# - [ ] **Plan van Aanpak** → UPLOAD: Plan_van_aanpak.md

# %% [markdown]
# ## PO - Onderzoekende houding

# %% [markdown]
# ### 4.1 Onderzoekende houding
# - [ ] **Domeinverkenning** → UPLOAD: Domeinverkenning.md
# - [ ] **Bronnen/literatuurlijst** → UPLOAD: Bronnen.md
# - [ ] **Methodische onderbouwing model-keuzes** → MAAK: Beschrijving waarom Random Forest, waarom 5-fold CV, etc.

# %% [markdown]
# ### 4.2 Domein- & werkveldverkenning
# - [ ] **2 interviews** → UPLOAD: Transcripties_Interviews_SmartHealth.md ✓
# - [ ] **Reflectie op vakgebied** → UPLOAD: Reflectieverslag_Interviews_SmartHealth.md ✓
# - [ ] **Analyse: communicatie in data-vakgebied** → MAAK: Hoe communiceren Jorg & Lieke? Welke taal gebruiken zij?

# %% [markdown]
# ### 4.3 Reflectie op eigen handelen
# - [ ] **STARR-reflectie Fase 1 (Domeinverkenning)** → MAAK: Situatie→Task→Action→Result→Reflection
# - [ ] **STARR-reflectie Fase 2 (EDA)** → MAAK: idem
# - [ ] **STARR-reflectie Fase 3 (ML-modellen)** → MAAK: idem
# - [ ] **STARR-reflectie Fase 4 (Dashboard)** → MAAK: idem
# - [ ] **STARR-reflectie Fase 5 (RAI/DPIA)** → MAAK: idem

# %% [markdown]
# ## TC - Data Science

# %% [markdown]
# ### 5.1 Datavisualisatie
# - [ ] **Dashboard Screenshot 1** → MAAK: Screenshot overview/home-tab met uitleg wat je ziet
# - [ ] **Dashboard Screenshot 2** → MAAK: Screenshot leefstijl-visualisatie (met uitleg design-keuzes)
# - [ ] **Dashboard Screenshot 3** → MAAK: Screenshot ML-model output (hart/bloeddruk)
# - [ ] **Dashboard Screenshot 4** → MAAK: Screenshot feature importance

# %% [markdown]
# ### 5.2 EDA
# - [ ] **EDA-rapport** → MAAK:
#   - Datakwaliteit overzicht (% missing per kolom)
#   - 3-4 key grafieken (bijv. verdeling scores, correlatie-matrix)
#   - Outliers & problemen gevonden
#   - Acties genomen

# %% [markdown]
# ### 5.3 Data-inzichten
# - [ ] **Model-bevindingen samenvat** → MAAK:
#   - Welke inzichten leverde elk model op?
#   - Relevantie voor Smart Health
#   - Limitations

# %% [markdown]
# ## TC - Machine Learning

# %% [markdown]
# ### 6.1 Feature Engineering
# - [ ] **Feature engineering rapport** → MAAK:
#   - Tabel: Feature | Type | Rationale | Transformatie
#   - Welke features weggelaten? Waarom?
#   - Feature interactions (bijv. leeftijd × slaap)

# %% [markdown]
# ### 6.2 Modelselectie & optimalisatie
# - [ ] **Model comparison tabel** → MAAK:
#   - Kolommen: Model | Hyperparameters | Accuracy | Recall_Matig | Recall_Hoog | F1
#   - Rows: Logistic Regression, Random Forest, Gradient Boosting
#   - Beste model gemarkeerd + reden

# %% [markdown]
# ### 6.3 Validatie & evaluatie
# - [ ] **Per model (Hartrisico, Bloeddruk, Leefstijl):**
#   - [ ] **Performance metrics tabel** → MAAK: Accuracy, Recall per klasse, F1, ROC-AUC
#   - [ ] **Confusion Matrix** → MAAK: Screenshot/grafiek per model
#   - [ ] **Feature Importance** → MAAK: Bar chart top 10 features per model
#   - [ ] **Cross-validatie resultaten** → MAAK: Tabel met mean ± std per fold
# - [ ] **Model-drift strategie** → MAAK: Hoe ga je model monitoren? Retraining-plan?

# %% [markdown]
# ## RAI - Responsible AI

# %% [markdown]
# ### 8.1 Signalering ethische/juridische vragen
# - [ ] **DPIA** → UPLOAD: DPIA_IAMA.md ✓
# - [ ] **Bias-check tabel** → MAAK:
#   - Kolommen: Subgroup (bijv. M/V, <40/>40) | Accuracy | Recall | F1 | Opmerking
#   - Rows: Per demografisch segment
#   - Conclusie: bias gevonden? Hoe mitigeren?

# %% [markdown]
# ### 8.2 Omgang met ethische vraagstukken
# - [ ] **Privacy-by-design implementatie** → MAAK:
#   - Beschrijving van maatregelen (gepseudonimisering, PC3, access control)
#   - Screenshot code of dashboard waar privacy zichtbaar
# - [ ] **Privacyplan** → UPLOAD: DPIA_IAMA.md (Privacy by design sectie)

# %% [markdown]
# ### 8.3 Data-eigenaarschap & verantwoordelijkheid
# - [ ] **Datamanagement plan** → MAAK:
#   - Diagram of tabel: wie is eigenaar/beheerder/gebruiker?
#   - Dataflow: hoe stroomt data door systeem?
#   - Bewaartermijnen per datatype

# %% [markdown]
# ### 8.4 Verantwoording
# - [ ] **IAMA (afmaken)** → MAAK: IAMA sectie in DPIA_IAMA.md completeren
# - [ ] **Theoretische onderbouwing** → MAAK:
#   - Hoe koppel je keuzes (bijv. asymmetrische weging recall) → theorie (AVG, IAMA, privacy-by-design)?
